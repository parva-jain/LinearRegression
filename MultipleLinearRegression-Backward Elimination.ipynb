# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('50_Startups.csv')

# %%
data_with_dummies = pd.get_dummies(data,drop_first = True)

# %%
data_with_dummies
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  State_Florida  \
# 0   165349.20       136897.80        471784.10  192261.83              0
# 1   162597.70       151377.59        443898.53  191792.06              0
# 2   153441.51       101145.55        407934.54  191050.39              1
# 3   144372.41       118671.85        383199.62  182901.99              0
# 4   142107.34        91391.77        366168.42  166187.94              1
# 5   131876.90        99814.71        362861.36  156991.12              0
# 6   134615.46       147198.87        127716.82  156122.51              0
# 7   130298.13       145530.06        323876.68  155752.60              1
# 8   120542.52       148718.95        311613.29  152211.77              0
# 9   123334.88       108679.17        304981.62  149759.96              0
# 10  101913.08       110594.11        229160.95  146121.95              1
# 11  100671.96        91790.61        249744.55  144259.40              0
# ...

# %%
y = data_with_dummies.iloc[:,3]

# %%
y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
x = data_with_dummies.drop('Profit',axis = 1 )

# %%
x
# Out:
#     R&D Spend  Administration  Marketing Spend  State_Florida  State_New York
# 0   165349.20       136897.80        471784.10              0               1
# 1   162597.70       151377.59        443898.53              0               0
# 2   153441.51       101145.55        407934.54              1               0
# 3   144372.41       118671.85        383199.62              0               1
# 4   142107.34        91391.77        366168.42              1               0
# 5   131876.90        99814.71        362861.36              0               1
# 6   134615.46       147198.87        127716.82              0               0
# 7   130298.13       145530.06        323876.68              1               0
# 8   120542.52       148718.95        311613.29              0               1
# 9   123334.88       108679.17        304981.62              0               0
# 10  101913.08       110594.11        229160.95              1               0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 66)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_hat = reg.predict(x_test)

# %%
y_hat
# Out:
# array([172447.31865773,  50420.08069681, 105042.6266472 , 162767.47017182,
#        189895.83042815,  51784.15208049, 151113.8700873 ,  91551.81258472,
#        130463.91464754,  76923.26381462])

# %%
y_test
# Out:
# 4     166187.94
# 47     42559.73
# 25    107404.34
# 5     156991.12
# 1     191792.06
# 49     14681.40
# 14    132602.65
# 37     89949.14
# 17    125370.37
# 41     77798.83
# Name: Profit, dtype: float64

# %%
import statsmodels.api as sm

# %%
x = np.append(arr = np.ones((50,1)).astype(int),values = x,axis = 1)

# %%
np.set_printoptions(formatter={'float_kind':'{:f}'.format})

# %%
x
# Out:
# array([[1.000000, 165349.200000, 136897.800000, 471784.100000, 0.000000,
#         1.000000],
#        [1.000000, 162597.700000, 151377.590000, 443898.530000, 0.000000,
#         0.000000],
#        [1.000000, 153441.510000, 101145.550000, 407934.540000, 1.000000,
#         0.000000],
#        [1.000000, 144372.410000, 118671.850000, 383199.620000, 0.000000,
#         1.000000],
#        [1.000000, 142107.340000, 91391.770000, 366168.420000, 1.000000,
#         0.000000],
#        [1.000000, 131876.900000, 99814.710000, 362861.360000, 0.000000,
#         1.000000],
#        [1.000000, 134615.460000, 147198.870000, 127716.820000, 0.000000,
#         0.000000],
#        [1.000000, 130298.130000, 145530.060000, 323876.680000, 1.000000,
#         0.000000],
#        [1.000000, 120542.520000, 148718.950000, 311613.290000, 0.000000,
#         1.000000],
#        [1.000000, 123334.880000, 108679.170000, 304981.620000, 0.000000,
#         0.000000],
# ...

# %%
x_opt = x[:,[0,1,2,3,4,5]]
regressor_OLS = sm.OLS(endog = y,exog = x_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     217.2
# Date:                Tue, 10 Mar 2020   Prob (F-statistic):           8.49e-29
# Time:                        14:37:01   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1061.
# Df Residuals:                      45   BIC:                             1070.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.505e+04   3323.935      7.537      0.000    1.84e+04    3.17e+04
# ...

# %%
x_opt = x[:,[0,1,2,3,4]]
regressor_OLS = sm.OLS(endog = y,exog = x_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Tue, 10 Mar 2020   Prob (F-statistic):           4.53e-30
# Time:                        14:42:48   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.506e+04   3286.176      7.626      0.000    1.84e+04    3.17e+04
# ...

# %%
x_opt = x[:,[0,1,2,4]]
regressor_OLS = sm.OLS(endog = y,exog = x_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     450.8
# Date:                Tue, 10 Mar 2020   Prob (F-statistic):           2.16e-31
# Time:                        14:47:59   Log-Likelihood:                -525.54
# No. Observations:                  50   AIC:                             1057.
# Df Residuals:                      47   BIC:                             1063.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.349e+04   1344.966     17.464      0.000    2.08e+04    2.62e+04
# ...

# %%
x_opt = x[:,[0,1,2]]
regressor_OLS = sm.OLS(endog = y,exog = x_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     849.8
# Date:                Tue, 10 Mar 2020   Prob (F-statistic):           3.50e-32
# Time:                        14:49:57   Log-Likelihood:                -527.44
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      48   BIC:                             1063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.452e+04   1268.948     19.320      0.000     2.2e+04    2.71e+04
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_opt,y,test_size = 0.2,random_state = 66)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_hat = reg.predict(x_test)

# %%
y_hat
# Out:
# array([171424.941291, 49900.790416, 104478.683286, 163255.976094,
#        189574.338151, 51036.638331, 151149.930416, 89686.443475,
#        131819.921836, 76081.970320])

# %%
y_test
# Out:
# 4     166187.94
# 47     42559.73
# 25    107404.34
# 5     156991.12
# 1     191792.06
# 49     14681.40
# 14    132602.65
# 37     89949.14
# 17    125370.37
# 41     77798.83
# Name: Profit, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_opt,y,test_size = 0.2,random_state = 66)


from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_hat = reg.predict(x_test)

# %%
y_hat
# Out:
# array([170510.101090, 51912.666561, 105879.398403, 161972.161121,
#        187610.583927, 51912.666561, 152012.777879, 88691.787258,
#        130909.967727, 75191.047210])

# %%
y_test
# Out:
# 4     166187.94
# 47     42559.73
# 25    107404.34
# 5     156991.12
# 1     191792.06
# 49     14681.40
# 14    132602.65
# 37     89949.14
# 17    125370.37
# 41     77798.83
# Name: Profit, dtype: float64
